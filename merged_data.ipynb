# %%
import pandas as pd

# %%
final_features_dataframe = pd.read_csv('final_dataframe.csv')
final_features_dataframe.head()
# Out:
#    Unnamed: 0   patient_id        file_key  Mean Zero Crossing Rate  Mean RMS  \
# 0           0  patient_001  MD_001_sup_Mit                 0.011958  0.143142
# 1           1  patient_002  MR_002_sup_Mit                 0.012210  0.165092
# 2           2  patient_003  MD_003_sup_Mit                 0.014092  0.173574
# 3           3  patient_004  MR_004_sup_Mit                 0.011700  0.108412
# 4           4  patient_005  AS_005_sup_Mit                 0.012714  0.148922
#
#    Standard Dev. RMS  Skewness RMS  Mean Spectral Centroid  \
# 0           0.034833     -1.096259               34.890196
# 1           0.027566     -0.316046               33.460782
# 2           0.043529      0.443779               37.845913
# 3           0.038909     -0.287181               34.718984
# 4           0.036316      0.305797               36.790153
#
#    Mean Spectral Bandwidth  Mean Spectral Contrast  mfcc length  \
# 0                40.113631               19.738395    10.477890
# 1                38.872170               21.016974    11.359635
# 2                37.872520               19.996377    12.039135
# 3                45.096458               20.884205     9.489616
# 4                47.651187               20.948300    11.572793
#
#                                        mfcc devation  mean mel spectogram  \
# 0  [5.3091073 5.950165  3.084269  2.7014892 3.689...             9.417829
# 1  [37.945606    7.4402657  10.91368     8.897607...            12.336461
# 2  [18.070349    5.320191    6.4636636   5.592787...            14.933869
# 3  [7.723736  9.400514  7.1840897 4.756417  3.603...             6.038412
# 4  [29.825611  11.928112  10.3983345  6.070464   ...            10.173615
#
#    mel spectrogram deviation   CQT Mean   CQT Std  CQT Skew
# 0                  82.951720  -6.482236  8.433458 -0.467773
# 1                  97.720480  -6.240110  8.148360 -0.839308
# 2                 122.661920  -3.309826  9.702022 -0.680768
# 3                  54.487843 -13.123395  9.085996 -0.361344
# 4                  82.876380  -5.738289  8.239526 -0.391299

# %%
melted_clean = pd.read_csv('melted_clean.csv')
melted_clean.head()
# Out:
#    Unnamed: 0   patient_id  AS  AR  MR  MS  N  Age Gender  Smoker Lives  \
# 0           0  patient_001   1   1   1   1  0   35      M       1     U
# 1           1  patient_002   0   0   1   0  0   37      M       1     U
# 2           2  patient_003   1   1   0   0  0   19      M       0     U
# 3           3  patient_004   0   0   1   0  0   21      M       0     R
# 4           4  patient_005   1   0   0   0  0   45      M       0     R
#
#   audio_filename_base        file_key  \
# 0      MD_001_sup_Mit  MD_001_sup_Mit
# 1      MR_002_sup_Mit  MR_002_sup_Mit
# 2      MD_003_sup_Mit  MD_003_sup_Mit
# 3      MR_004_sup_Mit  MR_004_sup_Mit
# 4      AS_005_sup_Mit  AS_005_sup_Mit
#
#                                           audio_path
# 0  /content/drive/My Drive/Heart Sounds/BMD-HS-Da...
# 1  /content/drive/My Drive/Heart Sounds/BMD-HS-Da...
# 2  /content/drive/My Drive/Heart Sounds/BMD-HS-Da...
# 3  /content/drive/My Drive/Heart Sounds/BMD-HS-Da...
# 4  /content/drive/My Drive/Heart Sounds/BMD-HS-Da...

# %%
open_Smle_df = pd.read_csv('open_modified.csv')
open_Smle_df.head()
# Out:
#    Unnamed: 0  loudness_sma3_amean  loudness_sma3_stddevNorm  \
# 0           0             0.052470                  0.625321
# 1           1             0.065124                  0.473485
# 2           2             0.063612                  0.603925
# 3           3             0.049348                  0.488492
# 4           4             0.067438                  0.376203
#
#    loudness_sma3_percentile20.0  loudness_sma3_percentile50.0  \
# 0                      0.030099                      0.042998
# 1                      0.037674                      0.059629
# 2                      0.032853                      0.047768
# 3                      0.029034                      0.043983
# 4                      0.047703                      0.062494
#
#    loudness_sma3_percentile80.0  loudness_sma3_pctlrange0-2  \
# 0                      0.064799                    0.034700
# 1                      0.089123                    0.051449
# 2                      0.103278                    0.070426
# 3                      0.066949                    0.037915
# 4                      0.083931                    0.036228
#
#    loudness_sma3_meanRisingSlope  loudness_sma3_stddevRisingSlope  \
# 0                       0.918415                         0.742484
# 1                       1.005707                         0.579594
# 2                       1.048375                         0.622853
# 3                       0.790192                         0.589207
# 4                       0.800198                         0.464654
#
#    loudness_sma3_meanFallingSlope  ...  alphaRatioUV_sma3nz_amean  \
# 0                        0.686833  ...                 -42.361408
# 1                        0.948674  ...                 -42.488987
# 2                        0.985896  ...                 -42.441883
# 3                        0.640581  ...                 -42.434982
# 4                        0.789672  ...                 -42.154606
#
#    hammarbergIndexUV_sma3nz_amean  slopeUV0-500_sma3nz_amean  \
# 0                       58.211384                  -0.093938
# 1                       58.230961                  -0.096479
# 2                       56.778862                  -0.093368
# 3                       57.377296                  -0.092384
# 4                       57.540642                  -0.095816
#
#    slopeUV500-1500_sma3nz_amean  spectralFluxUV_sma3nz_amean  \
# 0                      0.014711                     0.389258
# 1                      0.012956                     0.504070
# 2                      0.013366                     0.498946
# 3                      0.014799                     0.355016
# 4                      0.012141                     0.493245
#
#    loudnessPeaksPerSec  MeanUnvoicedSegmentLength  equivalentSoundLevel_dBp  \
# 0             4.902452                      19.93                -16.595591
# 1             5.152576                      19.93                -15.487094
# 2             5.552776                      19.93                -14.912294
# 3             5.102551                      19.93                -18.746437
# 4             5.452726                      19.93                -16.259226
#
#     patient_id        file_key
# 0  patient_001  MD_001_sup_Mit
# 1  patient_002  MR_002_sup_Mit
# 2  patient_003  MD_003_sup_Mit
# 3  patient_004  MR_004_sup_Mit
# 4  patient_005  AS_005_sup_Mit
#
# [5 rows x 77 columns]

# %%
final_features_dataframe = pd.merge(final_features_dataframe, open_Smle_df, on="file_key", how="left")
final_features_df = pd.merge(final_features_dataframe, melted_clean, on="file_key", how="left")

# %%
print(f" 1 = {len(final_features_dataframe.columns)}")
print('----------------')
print(f" 2 = {len(final_features_df.columns)}")
# Out:
#  1 = 93
# ----------------
#  2 = 106

# %%
final_features_df
# Out:
#      Unnamed: 0_x patient_id_x        file_key  Mean Zero Crossing Rate  \
# 0               0  patient_001  MD_001_sup_Mit                 0.011958
# 1               1  patient_002  MR_002_sup_Mit                 0.012210
# 2               2  patient_003  MD_003_sup_Mit                 0.014092
# 3               3  patient_004  MR_004_sup_Mit                 0.011700
# 4               4  patient_005  AS_005_sup_Mit                 0.012714
# ..            ...          ...             ...                      ...
# 858           858  patient_105   N_105_sit_Aor                 0.011504
# 859           859  patient_106   N_106_sit_Aor                 0.010419
# 860           860  patient_107   N_107_sit_Aor                 0.009464
# 861           861  patient_108   N_108_sit_Aor                 0.003866
# 862           862  patient_109   N_109_sit_Aor                 0.004345
#
#      Mean RMS  Standard Dev. RMS  Skewness RMS  Mean Spectral Centroid  \
# 0    0.143142           0.034833     -1.096259               34.890196
# 1    0.165092           0.027566     -0.316046               33.460782
# 2    0.173574           0.043529      0.443779               37.845913
# 3    0.108412           0.038909     -0.287181               34.718984
# 4    0.148922           0.036316      0.305797               36.790153
# ..        ...                ...           ...                     ...
# 858  0.187178           0.032507      0.051966               35.285902
# 859  0.203321           0.034671      0.125428               34.521189
# 860  0.166443           0.046930     -0.038828               33.521768
# 861  0.262939           0.042581      0.718949               31.699348
# 862  0.189189           0.062221     -0.410757               32.080001
#
#      Mean Spectral Bandwidth  Mean Spectral Contrast  ...  AR MR  MS  N  Age  \
# 0                  40.113631               19.738395  ...   1  1   1  0   35
# 1                  38.872170               21.016974  ...   0  1   0  0   37
# 2                  37.872520               19.996377  ...   1  0   0  0   19
# 3                  45.096458               20.884205  ...   0  1   0  0   21
# 4                  47.651187               20.948300  ...   0  0   0  0   45
# ..                       ...                     ...  ...  .. ..  .. ..  ...
# 858                46.440528               21.716723  ...   0  0   0  1   22
# 859                48.309507               21.559607  ...   0  0   0  1   20
# 860                45.466764               21.750754  ...   0  0   0  1   20
# 861                48.340479               22.133920  ...   0  0   0  1   20
# 862                53.162023               21.812159  ...   0  0   0  1   20
#
#      Gender  Smoker  Lives  audio_filename_base  \
# 0         M       1      U       MD_001_sup_Mit
# 1         M       1      U       MR_002_sup_Mit
# 2         M       0      U       MD_003_sup_Mit
# 3         M       0      R       MR_004_sup_Mit
# 4         M       0      R       AS_005_sup_Mit
# ..      ...     ...    ...                  ...
# 858       M       0      U        N_105_sit_Aor
# 859       F       0      U        N_106_sit_Aor
# 860       F       0      U        N_107_sit_Aor
# 861       F       0      U        N_108_sit_Aor
# 862       M       0      U        N_109_sit_Aor
#
#                                             audio_path
# 0    /content/drive/My Drive/Heart Sounds/BMD-HS-Da...
# 1    /content/drive/My Drive/Heart Sounds/BMD-HS-Da...
# 2    /content/drive/My Drive/Heart Sounds/BMD-HS-Da...
# 3    /content/drive/My Drive/Heart Sounds/BMD-HS-Da...
# 4    /content/drive/My Drive/Heart Sounds/BMD-HS-Da...
# ..                                                 ...
# 858  /content/drive/My Drive/Heart Sounds/BMD-HS-Da...
# 859  /content/drive/My Drive/Heart Sounds/BMD-HS-Da...
# 860  /content/drive/My Drive/Heart Sounds/BMD-HS-Da...
# 861  /content/drive/My Drive/Heart Sounds/BMD-HS-Da...
# 862  /content/drive/My Drive/Heart Sounds/BMD-HS-Da...
#
# [863 rows x 106 columns]

# %%
final_features_df.to_csv('completed_features_df.csv')
